# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
coco_df = pd.DataFrame(pd.read_csv(r'/home/liam/Documents/flavors_of_cacao.csv'))
coco_df.columns = ['Company', 'Specific_Origin', 'REF','Date','Cocoa_Perc', 'Company_Location', 'Rating', 'Bean_Type', 'Country_of_Origin']
coco_df
# Out:
#        Company     Specific_Origin   REF  Date Cocoa_Perc Company_Location  \
# 0     A. Morin         Agua Grande  1876  2016        63%           France
# 1     A. Morin               Kpime  1676  2015        70%           France
# 2     A. Morin              Atsane  1676  2015        70%           France
# 3     A. Morin               Akata  1680  2015        70%           France
# 4     A. Morin              Quilla  1704  2015        70%           France
# ...        ...                 ...   ...   ...        ...              ...
# 1790    Zotter                Peru   647  2011        70%          Austria
# 1791    Zotter               Congo   749  2011        65%          Austria
# 1792    Zotter        Kerala State   749  2011        65%          Austria
# 1793    Zotter        Kerala State   781  2011        62%          Austria
# 1794    Zotter  Brazil, Mitzi Blue   486  2010        65%          Austria
#
#       Rating  Bean_Type Country_of_Origin
# ...

# %%
# number of tuples
coco_df.count()
# Out:
# Company              1795
# Specific_Origin      1795
# REF                  1795
# Date                 1795
# Cocoa_Perc           1795
# Company_Location     1795
# Rating               1795
# Bean_Type            1794
# Country_of_Origin    1794
# dtype: int64

# %%
# number of Companies
coco_df['Company'].nunique()
# Out:
# 416

# %%
# number of ratings in 2013
coco_df.loc[coco_df['Date'] == 2013].count()
# Out:
# Company              184
# Specific_Origin      184
# REF                  184
# Date                 184
# Cocoa_Perc           184
# Company_Location     184
# Rating               184
# Bean_Type            184
# Country_of_Origin    184
# dtype: int64

# %%
# converting blanks to null values 
coco_null = coco_df.replace(r'^\s+$',np.nan, regex=True)
coco_null
# Out:
#        Company     Specific_Origin   REF  Date Cocoa_Perc Company_Location  \
# 0     A. Morin         Agua Grande  1876  2016        63%           France
# 1     A. Morin               Kpime  1676  2015        70%           France
# 2     A. Morin              Atsane  1676  2015        70%           France
# 3     A. Morin               Akata  1680  2015        70%           France
# 4     A. Morin              Quilla  1704  2015        70%           France
# ...        ...                 ...   ...   ...        ...              ...
# 1790    Zotter                Peru   647  2011        70%          Austria
# 1791    Zotter               Congo   749  2011        65%          Austria
# 1792    Zotter        Kerala State   749  2011        65%          Austria
# 1793    Zotter        Kerala State   781  2011        62%          Austria
# 1794    Zotter  Brazil, Mitzi Blue   486  2010        65%          Austria
#
#       Rating  Bean_Type Country_of_Origin
# ...

# %%
# counting nulls withing the Bean_Type column
len(coco_null) - coco_null['Bean_Type'].count()
# Out:
# 888

# %%
# visualization of cocolate ratings 
coco_df.hist(column='Rating')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efe09a02790>]],
#       dtype=object)
